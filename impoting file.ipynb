# %%
with open('name.txt','r') as file:
    print(file.readline())
# Out:
# neel

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
m=np.genfromtxt('new_wine.csv',skip_header=1)
m
# Out:
# array([nan, nan, nan, ..., nan, nan, nan])

# %%
m
# Out:
# array([nan, nan, nan, ..., nan, nan, nan])

# %%
import pandas as pd
df=pd.read_csv('Wine_Quality_Data.csv')
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %%
dk=df.drop(['color'], axis=1)

# %%
dm=dk.to_csv('new_wine.csv')

# %%
import pandas as pd
import pypyodbc

# %%
Driver="SQL Server"
Server="\SQL1"
Database="AdventureWorksLT2022"

connection=pypyodbc.connect(f"""
    DRIVER={{{Driver}}};
    SERVER={Server};
    DATABASE={Database};
    Trusted_Connection="yes";
    uid='noj';
    # password='123'
    """
)

# %%
query=pd.read_sql_query('''select * from [SalesLT].[Product]''',connection)
df=pd.DataFrame(query)
df
# Out:
# C:\Users\IT PARK\AppData\Local\Temp\ipykernel_6236\1192616449.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   query=pd.read_sql_query('''select * from [SalesLT].[Product]''',connection)
#      productid                       name productnumber  color  standardcost  \
# 0          680  HL Road Frame - Black, 58    FR-R92B-58  Black     1059.3100
# 1          706    HL Road Frame - Red, 58    FR-R92R-58    Red     1059.3100
# 2          707      Sport-100 Helmet, Red     HL-U509-R    Red       13.0863
# 3          708    Sport-100 Helmet, Black       HL-U509  Black       13.0863
# 4          709     Mountain Bike Socks, M     SO-B909-M  White        3.3963
# ..         ...                        ...           ...    ...           ...
# 290        995          ML Bottom Bracket       BB-8107   None       44.9506
# ...

# %%
df.to_csv('sqldata.csv')

# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymongo 
import pandas as pd
import json

# %%
client=pymongo.MongoClient("mongodb+srv://neelakandan:Neelakandan2001@neelakandan.f2q560b.mongodb.net/?retryWrites=true&w=majority")

# %%
db=client['MachineLearning']
coll1=db['Iris']

# %%
df=pd.read_csv('sqldata.csv')

# %%
data=df.to_dict(orient='records')

# %%
db.Iris.insert_many(data)

# %%
d=client.sample_mflix
k=d['movies']

# %%
m=[]
for i in k.find({"year":{"$lte":1920}},{"_id":0,"title":1,"year":1}):
    m.append(i)
df=pd.DataFrame(m)
#df.to_csv("ram.csv")
m[20]
# Out:
# {'title': 'The Kiss', 'year': 1896}

# %%
k=pd.DataFrame(m)
k
# Out:
#                                                 title  year
# 0                             The Great Train Robbery  1903
# 1                                        Regeneration  1915
# 2                                         The Italian  1915
# 3                     In the Land of the Head Hunters  1914
# 4                                       The Blue Bird  1918
# 5                               The Perils of Pauline  1914
# 6                              Where Are My Children?  1916
# 7                                     Wild and Woolly  1917
# 8                                            One Week  1920
# 9                           The Poor Little Rich Girl  1917
# 10  Winsor McCay, the Famous Cartoonist of the N.Y...  1911
# 11                                  A Corner in Wheat  1909
# 12                                 From Hand to Mouth  1919
# 13                                        The Saphead  1920
# 14                                   Traffic in Souls  1913
# ...

# %%
k.to_csv('mflix.csv')
